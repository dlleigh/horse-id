# %%
import pandas as pd
import numpy as np
import os

# %%
DATA_ROOT = os.environ.get('HORSE_ID_DATA_ROOT', '%s/google-drive/horseID Project/data' % os.environ.get('HOME', '.'))
MANIFEST_FILE = '%s/horse_photos_manifest.csv' % DATA_ROOT

# %%
manifest = pd.read_csv(MANIFEST_FILE)

# %%
manifest
# Out:
#     horse_name  email_date        message_id  \
# 0           Al    20250522  1973b8e512a9e9e1
# 1           Al    20250522  1973b8e512a9e9e1
# 2           Al    20250522  1973b8e512a9e9e1
# 3           Al    20250522  1973b8e512a9e9e1
# 4        Angie    20250528  1971c6c807b75195
# ..         ...         ...               ...
# 935       Zora    20250528  1971c65602eda5b9
# 936       Zora    20250528  1971c65602eda5b9
# 937       Zora    20250528  1971c65602eda5b9
# 938       Zora    20250528  1971c65602eda5b9
# 939       Zora    20250528  1971c65602eda5b9
#
#                                          filename  date_added status  \
# 0       Al-20250522-1973b8e512a9e9e1-IMG_5202.jpg  2025-06-05    NaN
# 1       Al-20250522-1973b8e512a9e9e1-IMG_5203.jpg  2025-06-05    NaN
# 2       Al-20250522-1973b8e512a9e9e1-IMG_5204.jpg  2025-06-05    NaN
# 3       Al-20250522-1973b8e512a9e9e1-IMG_5205.jpg  2025-06-05    NaN
# 4    Angie-20250528-1971c6c807b75195-IMG_6273.jpg  2025-06-05    NaN
# ..                                            ...         ...    ...
# 935   Zora-20250528-1971c65602eda5b9-IMG_6570.jpg  2025-06-05    NaN
# 936   Zora-20250528-1971c65602eda5b9-IMG_6571.jpg  2025-06-05    NaN
# 937   Zora-20250528-1971c65602eda5b9-IMG_6573.jpg  2025-06-05    NaN
# 938   Zora-20250528-1971c65602eda5b9-IMG_6575.jpg  2025-06-05    NaN
# 939   Zora-20250528-1971c65602eda5b9-IMG_6577.jpg  2025-06-05    NaN
#
#      is_ambiguous
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 935           NaN
# 936           NaN
# 937           NaN
# 938           NaN
# 939           NaN
#
# [940 rows x 7 columns]

# %%
manifest.to_csv(MANIFEST_FILE, index=False, 
                columns=['horse_name','email_date','message_id','filename','date_added','multi_horse_detected','status'],
                na_rep='')
